# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
data2 = pd.read_csv(r"C:\Users\anasw\OneDrive\Desktop\Datasets\bank-full - Copy.csv" , delimiter=';')
df = pd.DataFrame(data2)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
cols = df.select_dtypes('int64')
sns.heatmap(cols.corr())
plt.show()

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for_age = df[(df["age"] > 18) & (df["age"] <=30)]

# %%
plt.figure(figsize=(10,12))
sns.barplot( y = for_age["job"] , x = for_age["balance"] , palette='viridis' , edgecolor = 'black')
plt.title("Balances of individuals based on their Jobs Range(18 - 30)")
plt.show()
# Out:
# C:\Users\anasw\AppData\Local\Temp\ipykernel_1704\1940712788.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( y = for_age["job"] , x = for_age["balance"] , palette='viridis' , edgecolor = 'black')

# %%
plt.figure(figsize=(10,12))
sns.barplot( x = for_age["age"] , y = for_age["age"].value_counts() , palette='viridis' , edgecolor = 'black')
plt.title("Value counts of individuals Between 18 - 30")
plt.show()
# Out:
# C:\Users\anasw\AppData\Local\Temp\ipykernel_1704\1523439472.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( x = for_age["age"] , y = for_age["age"].value_counts() , palette='viridis' , edgecolor = 'black')

# %%
plt.figure(figsize=(10,12))
sns.barplot( x = for_age["age"] , y = for_age["age"].value_counts() , palette='viridis' , edgecolor = 'black')
plt.title("Value counts of individuals")
plt.show()
# Out:
# C:\Users\anasw\AppData\Local\Temp\ipykernel_1704\18352288.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( x = for_age["age"] , y = for_age["age"].value_counts() , palette='viridis' , edgecolor = 'black')

# %%
housing_counts = for_age['housing'].value_counts().reset_index()
default_counts = for_age['default'].value_counts().reset_index()

# %%
# Rename columns for clarity
housing_counts.columns = ['housing', 'counts']
default_counts.columns = ['default', 'counts']

# Plot
plt.figure(figsize=(10, 12))

sns.barplot(
    y=housing_counts['housing'], 
    x=housing_counts['counts'], 
    palette='viridis', 
    edgecolor='black'
)

plt.title("Value counts of individuals who are defaulters who own or do not own a house")
plt.xlabel("Count")
plt.ylabel("Own house")
plt.legend(title='Housing Status', labels=['Yes', 'No'])
plt.show()
# Out:
# C:\Users\anasw\AppData\Local\Temp\ipykernel_1704\438018597.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, precision_score,recall_score,f1_score

# %%
df["y"] = df["y"].apply(lambda x: 1 if x == "yes" else 0 )
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  unknown    5   may       261         1     -1         0  unknown  0
# 1  unknown    5   may       151         1     -1         0  unknown  0
# 2  unknown    5   may        76         1     -1         0  unknown  0
# 3  unknown    5   may        92         1     -1         0  unknown  0
# 4  unknown    5   may       198         1     -1         0  unknown  0

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

categorical_cols = df.select_dtypes(["object" , "category"]).columns


for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5      8       261         1     -1         0         3  0
# 1    5      8       151         1     -1         0         3  0
# 2    5      8        76         1     -1         0         3  0
# 3    5      8        92         1     -1         0         3  0
# 4    5      8       198         1     -1         0         3  0

# %%
X = df.drop(["y"] , axis = 1)
y = df["y"]

X_train , X_test , y_train , y_test = train_test_split(X,y, test_size= 0.30 , random_state= 1)

# %%
model = RandomForestClassifier()
model.fit(X_train , y_train)

model.score(X_train, y_train)
# Out:
# 0.9999684014282555

# %%
model.score(X_test , y_test)
# Out:
# 0.9054851076378649

# %%
cm = confusion_matrix(y_train, model.predict(X_train))

plt.figure(figsize=(6, 6))
labels = ["will not", "Will"]

# Create a heatmap with annotations
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.title("Confusion Matrix")
plt.show()

# %%
# Assuming y_test and model.predict(X_test) are already defined
cm = confusion_matrix(y_test, model.predict(X_test))

plt.figure(figsize=(6, 6))
labels = ["Will not", "Will "]

# Create a heatmap with annotations
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.title("Confusion Matrix")
plt.show()

# %%
recall = recall_score(y_train , model.predict(X_train))
precision = precision_score(y_train , model.predict(X_train))
f1_score_ = f1_score(y_train , model.predict(X_train))

print(recall)
print(precision)
print(f1_score_)
# Out:
# 1.0
# 1.0
# 1.0

# %%
recall = recall_score(y_test , model.predict(X_test))
precision = precision_score(y_test , model.predict(X_test))
f1_score_ = f1_score(y_test , model.predict(X_test))

print(recall)
print(precision)
print(f1_score_)
# Out:
# 0.4229529335912315
# 0.6289549376797698
# 0.5057825751734772

# %%
from sklearn.ensemble import GradientBoostingClassifier

model2 = GradientBoostingClassifier()
model2.fit(X_train,y_train)

model2.score(X_train , y_train)
# Out:
# 0.9102600562454577

# %%
model2.score(X_test , y_test)
# Out:
# 0.9028310232969625

# %%
cm = confusion_matrix(y_train, model2.predict(X_train))

plt.figure(figsize=(6, 6))
labels = ["will not", "Will"]

# Create a heatmap with annotations
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.title("Confusion Matrix")
plt.show()

# %%
cm = confusion_matrix(y_test, model2.predict(X_test))

plt.figure(figsize=(6, 6))
labels = ["will not", "Will"]

# Create a heatmap with annotations
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.title("Confusion Matrix")
plt.show()

# %%
recall2 = recall_score(y_train , model2.predict(X_train))
precision2 = precision_score(y_train , model2.predict(X_train))
f1_score_2 = f1_score(y_train , model2.predict(X_train))

print(recall2)
print(precision2)
print(f1_score_2)
# Out:
# 0.4328517924023542
# 0.6920444824636441
# 0.532587228439763

# %%
recall2_t = recall_score(y_test , model2.predict(X_test))
precision2_t = precision_score(y_test , model2.predict(X_test))
f1_score_2_t = f1_score(y_test , model2.predict(X_test))

print(recall2_t)
print(precision2_t)
print(f1_score_2_t)
# Out:
# 0.38555770470664086
# 0.6209761163032191
# 0.47573587907716786

# %% [markdown]
# Gradient boosting provides more balanced results compared to decision trees; however, decision trees yield better test scores.
